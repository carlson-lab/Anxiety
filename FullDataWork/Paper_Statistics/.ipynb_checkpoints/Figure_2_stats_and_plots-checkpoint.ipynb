# %%
import pandas as pd
from scipy.stats import wilcoxon, mannwhitneyu, ttest_ind, ttest_rel, ttest_1samp
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm 
from statsmodels.formula.api import ols
import seaborn as sns
import matplotlib.colors as colors
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize
from PIL import Image
from IPython.display import SVG, display
IM_PATH = "/hpc/home/mk423/Anxiety/FullDataWork/Figures/"

# %% [markdown]
# ## Figure 2.A

# %%
#Code for generating these circos plots can be found in: 
#/hpc/home/mk423/Anxiety/FullDataWork/Code/Figures/Color_Corrected_circos.ipynb

for i in range(3):
    display(SVG(IM_PATH + "color_corrected_final_circos_net_{}.svg".format(i)))

# %% [markdown]
# ## Figure 2.B and 2.C
#
# Figure 2B and 2C are generated by hand after interpretting the upper triangular plots found at color_corrected_final_upper_net_{}.svg.

# %% [markdown]
# ## Figure 2.D and 2.E
#
# Code for generating these figures is found in the final model trainig at /hpc/home/mk423/Anxiety/FullDataWork/Code/Training/Multitask/Final_Model_Training.ipynb
