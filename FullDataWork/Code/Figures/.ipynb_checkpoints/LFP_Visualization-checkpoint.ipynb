# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import numpy as np
filepath = "/work/mk423/Anxiety/Mouse0630_110717_EPM_LFP.mat"
plots_path = "/hpc/home/mk423/Anxiety/FullDataWork/Figures/"

dataDict = loadmat(filepath)

# %%
brain_regions = ['Amy_BLA_01', 'Cg_Cx_L_02', 'Hipp_01',
                 'IL_Cx_L_01', 'MD_Thal_01', 'NAc_Core_01',
                 'PrL_Cx_L_01', 'VTA_L_01']
br_label_list = ["VTA","PrL","NAc","MD_Thal","IL","Hipp","Cg","Amy"]

plt.figure(figsize=(30,10))
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)
for i, key in enumerate(brain_regions):
    bias = 8-i
    data = MinMaxScaler().fit_transform(dataDict[key][0,:6000].reshape(-1,1)).squeeze()
    
    plt.plot(data+bias,color="black")
     
for i in range(0,7000,1000):
    plt.axvline(i,linestyle="dashed",linewidth=5,color="red")
    
plt.yticks(np.arange(8)+1.5,br_label_list)
plt.yticks(fontsize=20)

plt.xticks(np.arange(0,7000,1000),['$v_{t-3}$','$v_{t-2}$','$v_{t-1}$','$v_{t}$',
                                   '$v_{t+1}$','$v_{t+2}$','$v_{t+3}$'])
plt.xticks(fontsize=30)

plt.xlim([500,5500])
plt.savefig(plots_path + "lfp_example_figure.pdf",format="pdf")
plt.show()

# %%
dataDict.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Amy_BLA_01', 'Amy_BLA_02', 'Amy_BLA_03', 'Amy_BLA_04', 'Amy_CeA_01', 'Amy_CeA_02', 'Cg_Cx_L_01', 'Cg_Cx_L_02', 'Cg_Cx_R_01', 'Cg_Cx_R_02', 'Hipp_01', 'Hipp_02', 'Hipp_03', 'IL_Cx_L_01', 'IL_Cx_R_01', 'MD_Thal_01', 'MD_Thal_02', 'MD_Thal_03', 'NAc_Core_01', 'NAc_Core_02', 'NAc_Core_03', 'NAc_Core_04', 'NAc_Shell_01', 'NAc_Shell_02', 'NAc_Shell_03', 'NAc_Shell_04', 'PrL_Cx_L_01', 'PrL_Cx_R_01', 'VTA_L_01', 'VTA_L_02', 'VTA_R_01', 'VTA_R_02'])
